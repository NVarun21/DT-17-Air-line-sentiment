# %%
import pandas as pd

# %%
df=pd.read_csv("Tweets.csv")

# %%
df
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
df['airline_sentiment'] = df['airline_sentiment'].replace({'positive': 1, 'negative': -1, 'neutral': 0})
# Out:
# C:\Users\nukan\AppData\Local\Temp\ipykernel_13980\3695921394.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['airline_sentiment'] = df['airline_sentiment'].replace({'positive': 1, 'negative': -1, 'neutral': 0})

# %%
pip install nltk
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\nukan\AppData\Roaming\Python\Python311\site-packages)
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nukan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

df = pd.read_csv('tweets.csv')

# Initialize the PorterStemmer
ps = PorterStemmer()

# Define a function to apply stemming
def stem_text(text):
    words = word_tokenize(text)  # Tokenize text
    stemmed_words = [ps.stem(word) for word in words]  # Apply stemming
    return ' '.join(stemmed_words)  # Join words back into a sentence

# Apply stemming to the 'text' column
df['stemmed_text'] = df['text'].apply(stem_text)

# Display result
print(df)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[58], line 17
#      14     return ' '.join(stemmed_words)  # Join words back into a sentence
#      16 # Apply stemming to the 'text' column
# ---> 17 df['stemmed_text'] = df['text'].apply(stem_text)
#      19 # Display result
#      20 print(df)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
# ...

# %%
import nltk
nltk.download('punkt', force=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nukan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True
